# %%
from selenium import webdriver
from selenium.webdriver.remote.webelement import WebElement
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from bs4 import BeautifulSoup
import requests
import pandas as pd
import csv
import time
import pyautogui as gui
import pyperclip

# %%
browser = webdriver.Chrome('C:\chromedriver.exe')
browser.get('https://www.bigkinds.or.kr/v2/news/index.do')

# %%
browser.find_element_by_xpath("//label[@for='경향신문']").click()

# %%
browser.find_element_by_xpath("//button[@class='btn btn-search news-search-btn news-report-search-btn']").click()

# %%
WebDriverWait(browser, 5).until(EC.presence_of_element_located((By.XPATH, "//select[@id='select2']/option[4]")))
browser.find_element_by_xpath("//select[@id='select2']/option[4]").click()

# %%
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
wholes = soup.select('div.news-inner')

# %%
len(wholes)
# Out:
# 100

# %%
contents = [] # [제목, 언론사, 분류, 날짜, 기자이름, 기사내용]
for whole in wholes:
    title = whole.select('span.title-elipsis')
    press =  whole.select('div.info > div > a')
    category = whole.select('div.info > div > span.bullet-keyword')
    date_name = whole.select('div.info > p')
    contents.append([title[0].text.strip(), press[0].text.strip(), category[0].text.strip(), date_name[0].text.strip(), date_name[1].text.strip()])
len(contents)
# Out:
# 100

# %%
texts = []
for i in range(0, 100):
    browser.find_elements_by_css_selector('span.title-elipsis')[i].click()
    time.sleep(1)
    text = browser.find_elements_by_css_selector('div.news-view-body')[0].text
    texts.append(text.replace('\n', ''))
    browser.find_element_by_xpath("//div[@id='news-detail-modal']/div/div/button").click()
len(texts)
# Out:
# 100

# %%
contents
# Out:
# [['[뉴스분석]이준석과 윤석열은 왜 대립할까···‘투스톤’의 이유있는 신경전',
#   '경향신문',
#   '정치>선거 | 정치>국회_정당',
#   '2021/08/11',
#   '박순봉·유정인 기자 gabgu@kyunghyang.com'],
#  ['중국에 대립각 세우는 리투아니아…왜?',
#   '경향신문',
#   '국제>중국 | 정치>외교 | 국제>유럽_EU',
#   '2021/08/11',
#   '박은하 기자 eunha999@kyunghyang.com'],
#  ['국민의힘, 계속 옮겨붙는 갈등의 불씨...진화할 수 있을까',
#   '경향신문',
#   '정치>선거 | 정치>국회_정당',
#   '2021/08/11',
#   '유정인·박순봉 기자 jeongin@kyunghyang.com'],
#  ['[단독] 법관이 직원에게 성경 공부·의전 지시, 법원에서도 ‘직장 갑질’ 논란',
#   '경향신문',
#   '국제>미국_북미 | 국제>유럽_EU | 사회>여성',
#   '2021/08/11',
#   '이혜리 기자 lhr@kyunghyang.com'],
#  ['코로나 확진자수 2000명 돌파에 노심초사 여, 공세 강화하는 야',
#   '경향신문',
#   '정치>국회_정당 | 정치>청와대',
#   '2021/08/11',
#   '유설희 기자 sorry@kyunghyang.com'],
#  ['류호정 "피해자 보호 못하는 강간죄 개정 위해 \'쇼\'라도 하겠다"',
#   '경향신문',
#   '정치>행정_자치 | 사회>여성 | 정치>국회_정당',
#   '2021/08/11',
#   '장은교 소통·젠더데스크 indi@kyunghyang.com'],
#  ['[뉴스분석]현실화된 정은경의 예언···확진자 2223명이 정점은 아니다',
#   '경향신문',
#   '사회>의료_건강',
#   '2021/08/11',
#   '노도현·김향미·이혜리 기자 hyunee@kyunghyang.com'],
#  ['[비동의강간죄 발의 1년]이 법은 또 사라지는 중입니까?',
#   '경향신문',
#   '사회>여성 | 정치>행정_자치 | 정치>국회_정당',
#   '2021/08/11',
#   '장은교 소통·젠더데스크 indi@kyunghyang.com'],
#  ['윤석열, 통신선 복원 \'이면협의\' 의혹제기, 청와대 "사실 아니다"',
#   '경향신문',
#   '정치>북한 | 정치>청와대',
#   '2021/08/11',
#   '심진용 기자 sim@kyunghyang.com'],
#  ["김여정 '주한미군 철수 주장' 담화의 의미는",
#   '경향신문',
#   '정치>외교 | 정치>북한 | 정치>청와대',
#   '2021/08/11',
#   '유신모 기자 simon@kyunghyang.com'],
#  ["인건비 늘고 신작 출시 지연···게임 '3N', 나란히 2분기 실적부진",
#   '경향신문',
#   '경제>유통 | IT_과학>콘텐츠 | 경제>증권_증시',
#   '2021/08/11',
#   '이유진 기자 yjleee@kyunghyang.com'],
#  ['2024년 \'달 착륙 계획’ 지연 되나…"신형 우주복 개발 늦어져"',
#   '경향신문',
#   'IT_과학>과학',
#   '2021/08/11',
#   '이정호 기자 run@kyunghyang.com'],
#  ['[인터랙티브] “이 법은 또 사라지는 중입니까”…비동의강간죄 발의 1년, 여전히 계류중',
#   '경향신문',
#   '정치>행정_자치 | 정치>국회_정당 | 정치>선거',
#   '2021/08/11',
#   '장은교 기자 indi@kyunghyang.com김유진 기자 이수민 인턴기자'],
#  ['더 가까워지는 중·러, 고비사막에서 사흘째 합동군사훈련',
#   '경향신문',
#   '국제>중국 | 국제>유럽_EU | 국제>일본',
#   '2021/08/11',
#   '박은하 기자 eunha999@kyunghyang.com'],
#  ['‘호프 알바’ 나선 정의당 대표…현장 행보로 ‘차별화’하면서 대선 준비 시동',
#   '경향신문',
#   '정치>국회_정당 | 정치>선거',
#   '2021/08/11',
#   '김상범 기자 ksb1231@kyunghyang.com'],
#  ['코로나19 재확산에 온라인 유통망 발달까지…창신동 문구거리의 ‘깊어지는 시름’',
#   '경향신문',
#   '경제>유통',
#   '2021/08/11',
#   '김태희 기자 kth08@kyunghyang.com'],
#  ['최재형 “여당은 청와대 출장소···비서관들이 국정 쥐락펴락” 문 대통령 성토',
#   '경향신문',
#   '정치>청와대 | 정치>국회_정당 | 정치>행정_자치',
#   '2021/08/11',
#   '유설희 기자 sorry@kyunghyang.com'],
#  ["온난화에 '통제 불능' 미국·유럽 산불…미래의 예고편?",
#   '경향신문',
#   '사회>날씨',
#   '2021/08/11',
#   '김한솔 기자 hansol@kyunghyang.com'],
#  ["“집단면역 불가능”…영국·싱가포르의 '코로나와 함께 살기' 실험",
#   '경향신문',
#   '국제>아시아 | 국제>유럽_EU | 사회>의료_건강',
#   '2021/08/11',
#   '김윤나영 기자 nayoung@kyunghyang.com'],
#  ['모더나 실무협의 위해 이번주 출국하는 정부대표단, 수급 차질 해법 있나',
#   '경향신문',
#   '경제>유통 | 경제>자동차',
#   '2021/08/11',
#   '김향미 기자 sokhm@kyunghyang.com'],
#  ['문 대통령, 국회에 고승범·송두환 후보자 인사청문 요청',
#   '경향신문',
#   '정치>국회_정당 | 정치>청와대 | 정치>북한',
#   '2021/08/11',
#   '정대연 기자 hoan@kyunghyang.com'],
#  ['국민의힘, 대선 후보 토론만 20회···흥행 묘수될까, 분란 씨앗될까',
#   '경향신문',
#   '정치>선거 | 정치>국회_정당',
#   '2021/08/11',
#   '심진용 기자 sim@kyunghyang.com'],
#  ['이재용 가석방에 ‘침묵’하는 문 대통령…여당서도 “가석방 이유 궁색”',
#   '경향신문',
#   '정치>청와대 | 정치>국회_정당 | 정치>선거',
#   '2021/08/11',
#   '정대연 기자 hoan@kyunghyang.com'],
#  ['황의탁 전북도의원 의정비 전액 복지시설에 ‘통 큰’ 기부',
#   '경향신문',
#   '지역>경기 | 사회>장애인 | 지역>전북',
#   '2021/08/11',
#   '박용근 기자 yk21@kyunghyang.com'],
#  ['[경향포토] 경실련 이재용 가석방 반대 1인시위',
#   '경향신문',
#   '정치>청와대 | 정치>국회_정당',
#   '2021/08/11',
#   '김기남 기자 kknphoto@kyunghyang.com'],
#  ['‘명·낙 대전’ 꺾이지 않는 상호 비방전…당 내선 “지도부가 중심잡아야”',
#   '경향신문',
#   '정치>국회_정당 | 정치>선거',
#   '2021/08/11',
#   '윤승민 기자 mean@kyunghyang.com'],
#  ['소형 SUV 2강 자리 굳힌 트레일블레이저, 프리미엄 전략 통했다',
#   '경향신문',
#   '경제>자동차 | IT_과학>모바일 | 경제>유통',
#   '2021/08/11',
#   '노정연 기자 dana_fm@kyunghyang.com'],
#  ["가상자산 거래소 '불공정 약관' 손질에도 소비자 마음 못 놓는 이유는?",
#   '경향신문',
#   '경제>증권_증시 | 경제>서비스_쇼핑 | 경제>금융_재테크',
#   '2021/08/11',
#   '박상영 기자 sypark@kyunghyang.com'],
#  ['연상의 아내 마지막 출근길···가난한 시인은 눈물을 적셔 편지를 썼다',
#   '경향신문',
#   '문화>출판 | 문화>생활 | 문화>방송_연예',
#   '2021/08/11',
#   '박용근 기자 yk21@kyunghyang.com'],
#  ['“홍남기, 법무장관에 ‘이재용 경영활동, 불편없게 해달라’ 요청”',
#   '경향신문',
#   '경제>무역 | 경제>취업_창업 | 정치>정치일반',
#   '2021/08/11',
#   '안광호 기자 ahn7874@kyunghyang.com'],
#  ["호주, 인공지능(AI)을 '발명자'로 세계 최초 인정···한국은?",
#   '경향신문',
#   '국제>국제일반 | IT_과학>과학',
#   '2021/08/11',
#   '윤희일 선임기자 yhi@kyunghyang.com'],
#  ['LH 조직개편 어디로 가나…"\'분리\' 아닌 주거복지 강화에 초점둬야"',
#   '경향신문',
#   '정치>정치일반',
#   '2021/08/11',
#   '김희진 기자 hjin@kyunghyang.com'],
#  ['코로나 확산에도 여름 휴가철 제주는 ‘비틀’···위험천만 음주운전 증가',
#   '경향신문',
#   '지역>제주 | 지역>충남 | 지역>울산',
#   '2021/08/11',
#   '박미라 기자 mrpark@kyunghyang.com'],
#  ['충주시 유튜브 채널 ‘충TV’ 구독자 20만 돌파···전국 지자체 유튜브 중 최다',
#   '경향신문',
#   '미분류',
#   '2021/08/11',
#   '이삭 기자 isak84@kyunghyang.com'],
#  ['"화이자·모더나 백신 2차접종일 추석 연휴 겹치면 5일씩 앞당기기로"',
#   '경향신문',
#   '지역>강원 | 사회>의료_건강 | 지역>전북',
#   '2021/08/11',
#   '김향미 기자 sokhm@kyunghyang.com'],
#  ['[경북도]경북농업기술원, 25일까지 농민 대상 디지털농업 교육',
#   '경향신문',
#   '지역>전북 | 지역>충북 | 지역>충남',
#   '2021/08/11',
#   '백경열 기자 merci@kyunghyang.com'],
#  ['‘5G 덕에’ 통신 3사 실적 날았는데···품질에 뿔난 소비자들은 정부 대책 촉구',
#   '경향신문',
#   'IT_과학>모바일 | 경제>유통',
#   '2021/08/11',
#   '이유진 기자 yjleee@kyunghyang.com'],
#  ['수익형 부동산 투자 주목 단지 어디…복합스트리트쇼핑몰 ‘시화MTV 보니타가’ 분양 화제',
#   '경향신문',
#   '경제>부동산 | 지역>대구 | 지역>경기',
#   '2021/08/11',
#   '김경은 기자 jjj@khan.kr'],
#  ['올림픽은 망명신청 선수들의 ‘환승센터’',
#   '경향신문',
#   '국제>유럽_EU | 국제>아시아',
#   '2021/08/11',
#   '윤기은 기자 energyeun@kyunghyang.com'],
#  ['미국, 석탄→신재생에너지 ‘광속’ 전환…풍력·태양광 전년 대비 2배 성장',
#   '경향신문',
#   '경제>자원',
#   '2021/08/11',
#   '노정연 기자 dana_fm@kyunghyang.com'],
#  ['법원 “정경심 딸 7대 스펙 모두 허위”···부산대 이어 고려대도 입학 자체조사',
#   '경향신문',
#   '사회>교육_시험 | 사회>미디어',
#   '2021/08/11',
#   '이호준 기자 hjlee@kyunghyang.com'],
#  ['서울국제여성영화제 26일 개막···개막작은 ‘무민’ 작가 토베 얀손의 퀴어 예술가 삶 조명 다큐',
#   '경향신문',
#   '문화>영화 | 문화>전시_공연 | 문화>방송_연예',
#   '2021/08/11',
#   '백승찬 기자 myungworry@kyunghyang.com'],
#  ['뜨거워지는 지구, 전 세계 식량 생산도 위태롭다…"식단 전환 필요"',
#   '경향신문',
#   '경제>유통 | 국제>유럽_EU | 경제>자원',
#   '2021/08/11',
#   '박하얀 기자 white@kyunghyang.com'],
#  ['황인찬 시로 엮은 영화 ‘생각의 여름’, 시인 황인찬이 말하다',
#   '경향신문',
#   '문화>영화 | 문화>방송_연예 | 문화>출판',
#   '2021/08/11',
#   '김지혜 기자 kimg@kyunghyang.com'],
#  ['[일상, ___ ] 끈',
#   '경향신문',
#   '문화>방송_연예 | 문화>출판',
#   '2021/08/11',
#   '강윤중 기자 yaja@kyunghyang.com'],
#  ["EU 아프간 난민 고민 심화...독일 등 6개 회원국은 집행위에 '강제 추방' 보장 요구",
#   '경향신문',
#   '국제>유럽_EU | 국제>중동_아프리카 | 국제>아시아',
#   '2021/08/11',
#   '박용하 기자 yong14h@kyunghyang.com'],
#  ['코로나19 신용 사면, 소액 연체하고 전액 상환한 경우만 가능',
#   '경향신문',
#   '경제>금융_재테크',
#   '2021/08/11',
#   '박효재 기자 mann616@kyunghyang.com'],
#  ['대구~양양 하늘길 재개…“여행욕구 충족, 공항 활성화”',
#   '경향신문',
#   '지역>대구 | 지역>강원 | 지역>경남',
#   '2021/08/11',
#   '박태우 기자 taewoo@kyunghyang.com'],
#  ['김학순 할머니 피해 증언 30주년…정의기억연대 “할머니의 용기가 우리의 용기 돼”',
#   '경향신문',
#   '국제>일본 | 사회>사회일반 | 국제>유럽_EU',
#   '2021/08/11',
#   '민서영 기자 mins@kyunghyang.com'],
#  ['‘경단녀 장롱면허’로 서울시 산하기관 인턴십…취업까지 지원',
#   '경향신문',
#   '사회>여성 | 사회>장애인',
#   '2021/08/11',
#   '허남설 기자 nsheo@kyunghyang.com'],
#  ['"계곡 자릿세 요구 시 5000만원 벌금" 하천법 개정안 발의',
#   '경향신문',
#   '정치>정치일반 | 지역>경기 | 사회>사회일반',
#   '2021/08/11',
#   '송진식 기자 truejs@kyunghyang.com'],
#  ['‘소멸시효’ 일본 전범기업 면죄부 안돼···시민단체 특별법 제정 요구',
#   '경향신문',
#   '미분류',
#   '2021/08/11',
#   '강현석 기자 kaja@kyunghyang.com'],
#  ['고려대 “조국 딸 입시 비리 의혹, 후속조치 진행할 것”',
#   '경향신문',
#   '사회>교육_시험 | 사회>사건_사고',
#   '2021/08/11',
#   '문광호 기자 moonlit@kyunghyang.com'],
#  ['여전한 정치권 ‘유리천장’…국회의원 여성할당제 남녀 의견 판이',
#   '경향신문',
#   '사회>여성 | 정치>국회_정당',
#   '2021/08/11',
#   '반기웅 기자 ban@kyunghyang.com'],
#  ['박범계의 ‘한입 두말’…“재벌 총수 걱정 말라”더니 이재용 가석방',
#   '경향신문',
#   '정치>청와대 | 정치>행정_자치 | 정치>국회_정당',
#   '2021/08/11',
#   '허진무 기자 imagine@kyunghyang.com'],
#  ['트위터 알고리즘은 무슬림·흑인·노인을 차별한다',
#   '경향신문',
#   '사회>사회일반 | 국제>미국_북미 | 국제>중동_아프리카',
#   '2021/08/11',
#   '김윤나영 기자 nayoung@kyunghyang.com'],
#  ['파리바게뜨 ‘노조 와해’ 의혹에 증거인멸···관리자 카톡방 ‘폭파’ 정황',
#   '경향신문',
#   '사회>노동_복지 | 사회>미디어',
#   '2021/08/11',
#   '조해람 기자 · 한수빈 기자 lennon@kyunghyang.com'],
#  ['발전5사 ‘백신 차별’에, 노조 “비인간적 행위에 경악…모든 노동자 접종계획 수립해야”',
#   '경향신문',
#   '사회>노동_복지 | 사회>여성',
#   '2021/08/11',
#   '고희진 기자 gojin@kyunghyang.com'],
#  ["올해 수도권 공공분양 21년만에 '최대'",
#   '경향신문',
#   '경제>부동산 | 경제>유통',
#   '2021/08/11',
#   '송진식 기자 truejs@kyunghyang.com'],
#  ['“국회 세종의사당 위한 국회법 개정안 9월 정기국회에는 꼭 처리하라”...충청권 4개 시도지사 촉구',
#   '경향신문',
#   '정치>국회_정당 | 정치>행정_자치 | 정치>선거',
#   '2021/08/11',
#   '윤희일 선임기자 yhi@kyunghyang.com'],
#  ['‘메타버스게임과’ ‘AI전자과’…신입생 충원율 떨어진 특성화고, 학과 개편',
#   '경향신문',
#   'IT_과학>IT_과학일반 | 사회>교육_시험',
#   '2021/08/11',
#   '이하늬 기자 hanee@kyunghyang.com'],
#  ['산골 요양 암환자 위해 전신주 28개 연결한 LG유플러스',
#   '경향신문',
#   'IT_과학>모바일 | IT_과학>인터넷_SNS',
#   '2021/08/11',
#   '조미덥 기자 zorro@kyunghyang.com'],
#  ["코로나19에도 8월 수출 '상승세'",
#   '경향신문',
#   '경제>무역 | 경제>유통 | 경제>증권_증시',
#   '2021/08/11',
#   '박상영 기자 sypark@kyunghyang.com'],
#  ['생활ESG영화제 안치용 위원장 “ESG 생활 속 확산 위한 첫 영화제 9월 남양주에서 개막…청년들의 적극 참여 기대”',
#   '경향신문',
#   '문화>전시_공연 | 문화>영화',
#   '2021/08/11',
#   '문주영 기자 mooni@kyunghyang.com'],
#  ['이낙연 “지방 거점 국립대, ‘등록금 없는 대학’ 만들겠다”',
#   '경향신문',
#   '사회>교육_시험',
#   '2021/08/11',
#   '김상범 기자 ksb1231@kyunghyang.com'],
#  ['‘문 대통령 관련 막말’ 소마 공사, 도쿄로 출국···“사실상 경질”',
#   '경향신문',
#   '국제>일본 | 정치>외교 | 정치>청와대',
#   '2021/08/11',
#   '이윤정 기자 yyj@kyunghyang.com'],
#  ['선정위원의 동일기관 미고지 심사대상자는 1명…베니스 비엔날레 감독 재심사 1차 결과 발표',
#   '경향신문',
#   '문화>전시_공연',
#   '2021/08/11',
#   '김종목 기자 jomo@kyunghyang.com'],
#  ['SKT, 올 2분기 영업익 11% 증가···미디어·커머스 등 신사업 성장 영향',
#   '경향신문',
#   '경제>유통 | IT_과학>모바일 | IT_과학>콘텐츠',
#   '2021/08/11',
#   '이유진 기자 yjleee@kyunghyang.com'],
#  ['제주도 “모더나 혈전증 검사 의뢰 때 이미 혈소판수 기준 이하” 질병청 해명 반박',
#   '경향신문',
#   '사회>의료_건강 | 지역>경남 | 지역>제주',
#   '2021/08/11',
#   '박미라 기자 mrpark@kyunghyang.com'],
#  ['이 와중에 ‘8명 술자리’ 가진 서울시 ‘방역위반 단속’ 수장',
#   '경향신문',
#   '사회>장애인',
#   '2021/08/11',
#   '허남설 기자 nsheo@kyunghyang.com'],
#  ['아이를 낳다 죽음을 맞이한 14세 소녀 마차야가 남긴 것[플랫]',
#   '경향신문',
#   '사회>여성 | 국제>아시아 | 국제>중동_아프리카',
#   '2021/08/11',
#   '플랫팀 twitter.com/flatflat38'],
#  ['양경수 민주노총 위원장, 구속영장심사 불출석…“문재인 정부·민주당이 촛불 배신”',
#   '경향신문',
#   '사회>사건_사고 | 사회>노동_복지 | 정치>국회_정당',
#   '2021/08/11',
#   '이혜리 기자 lhr@kyunghyang.com'],
#  ['확진판정 20대, 백신 접종 후 또 확진···전북서 재감염 첫 사례',
#   '경향신문',
#   '지역>전북 | 사회>사회일반 | 지역>제주',
#   '2021/08/11',
#   '박용근 기자 yk21@kyunghyang.com'],
#  ['[경향포토] 세계 일본군 위안부 기림일 앞두고 열린 수요시위',
#   '경향신문',
#   '국제>일본 | 국제>유럽_EU',
#   '2021/08/11',
#   '강윤중 기자'],
#  ['[경향포토] 김학순 할머니 위안부 피해 공개증언 30년...계속되는 수요시위',
#   '경향신문',
#   '사회>사회일반',
#   '2021/08/11',
#   '강윤중 기자 yaja@kyunghyang.com'],
#  ['중국, 캐나다인 사업가에 징역 11년 선고…연이은 캐나다인 중형 판결',
#   '경향신문',
#   '국제>중국 | 국제>미국_북미 | 국제>중동_아프리카',
#   '2021/08/11',
#   '박은하 기자 eunha999@kyunghyang.com'],
#  ["중소·벤처기업 '공용 화상 회의실' 전국 오픈",
#   '경향신문',
#   '지역>경기 | 경제>무역 | 지역>경남',
#   '2021/08/11',
#   '김은성 기자 kes@kyunghyang.com'],
#  ['"가상세계 건축자들 모여라"…과기정통부, 메타버스 개발자 경진대회 개최',
#   '경향신문',
#   'IT_과학>인터넷_SNS | IT_과학>콘텐츠',
#   '2021/08/11',
#   '이정호 기자 run@kyunghyang.com'],
#  ['상반기 국내은행 순이익 10조8000억원...1년 전보다 4조원 증가',
#   '경향신문',
#   '경제>유통 | 경제>금융_재테크 | 경제>증권_증시',
#   '2021/08/11',
#   '정원식 기자 bachwsik@kyunghyang.com'],
#  ["내년 '빨간 날' 67일···최장 연휴는 설날 전후 '닷새'",
#   '경향신문',
#   '미분류',
#   '2021/08/11',
#   '이정호 기자 run@kyunghyang.com'],
#  ["제조 위탁·대금 정산 등 하도급법 위반 '종합세트' 가구업체 코아스 제재",
#   '경향신문',
#   '경제>산업_기업 | 경제>유통 | 경제>서비스_쇼핑',
#   '2021/08/11',
#   '박상영 기자 sypark@kyunghyang.com'],
#  ['쿠오모 성추행 스캔들에…최초 여성 뉴욕 주지사 취임',
#   '경향신문',
#   '국제>미국_북미 | 정치>국회_정당 | 사회>사회일반',
#   '2021/08/11',
#   '윤기은 기자 energyeun@kyunghyang.com'],
#  ['김명수 대법원장, 새 대법관에 오경미 고법판사 임명 제청',
#   '경향신문',
#   '사회>여성 | 사회>사건_사고 | 사회>교육_시험',
#   '2021/08/11',
#   '허진무 기자 imagine@kyunghyang.com'],
#  ['치명률 낮아졌지만 시민 70% 이상 “방역 전환은 아직 일러, 백신 맞겠다”',
#   '경향신문',
#   '사회>여성',
#   '2021/08/11',
#   '김향미 기자 sokhm@kyunghyang.com'],
#  ['BC카드·이마트24, 데이터 협력 MOU 체결',
#   '경향신문',
#   '경제>유통 | IT_과학>인터넷_SNS | IT_과학>보안',
#   '2021/08/11',
#   '박효재 기자 mann616@kyunghyang.com'],
#  ['원희룡 제주지사 11일 퇴임 “국민 지키기 위해 지사직 물러나”',
#   '경향신문',
#   '지역>제주 | 지역>충남 | 지역>강원',
#   '2021/08/11',
#   '박미라 기자 mrpark@kyunghyang.com'],
#  ['서울도 하루 확진자 역대 최다···“600명대 지속되면 병상 부족 우려”',
#   '경향신문',
#   '사회>사회일반',
#   '2021/08/11',
#   '허남설 기자 nsheo@kyunghyang.com'],
#  ['김두관 “서울공화국 해체” 균형발전 공약 발표…지자체 명칭 지방정부로',
#   '경향신문',
#   '정치>국회_정당 | 정치>선거',
#   '2021/08/11',
#   '박광연 기자 lightyear@kyunghyang.com'],
#  ['문 대통령 “감염 확산 못 막으면 확진자 더 늘어날 중요한 시점”',
#   '경향신문',
#   '정치>청와대',
#   '2021/08/11',
#   '정대연 기자 hoan@kyunghyang.com'],
#  ['[경향포토] "입시 비리 전부 유죄"...정경심 항소심도 징역 4년',
#   '경향신문',
#   '사회>사건_사고',
#   '2021/08/11',
#   '강윤중 기자'],
#  ['“무의미한 연명의료 안받겠다” 의향서 작성자 100만명 돌파',
#   '경향신문',
#   '사회>의료_건강',
#   '2021/08/11',
#   '노도현'],
#  ['현대백화점, 와인선물 종이포장재로 바꾼다',
#   '경향신문',
#   '경제>서비스_쇼핑 | 경제>유통',
#   '2021/08/11',
#   '정유미 기자 youme@kyunghyang.com'],
#  ['‘끓는 바다’ 경남 양식어류 집단폐사 급증···477만 마리 폐사',
#   '경향신문',
#   '지역>강원 | 지역>경남 | 지역>제주',
#   '2021/08/11',
#   '백승목 기자 smbaek@kyunghyang.com'],
#  ["[속보]정경심 '입시비리·사모펀드' 의혹, 2심도 징역 4년",
#   '경향신문',
#   '사회>사건_사고 | 사회>교육_시험 | 사회>노동_복지',
#   '2021/08/11',
#   '전현진 기자 jjin23@kyunghyang.com'],
#  ["서울시, 감염병 특화 '서울의료원 응급의료센터' 신축···9월말 정식운영",
#   '경향신문',
#   '사회>의료_건강 | 지역>경남 | 지역>제주',
#   '2021/08/11',
#   '류인하 기자 acha@kyunghyang.com'],
#  ['죽파리 자작나무 숲 인근 ‘송하리 졸참나무와 당숲’ 천연기념물 된다',
#   '경향신문',
#   '문화>학술_문화재 | 문화>미술_건축 | 지역>강원',
#   '2021/08/11',
#   '김종목 기자 jomo@kyunghyang.com'],
#  ['섬유·제지 산업도 탄소중립 움직임···"폐자원을 에너지로"',
#   '경향신문',
#   '경제>반도체 | 지역>강원 | 지역>충남',
#   '2021/08/11',
#   '강연주 기자 play@kyunghyang.com'],
#  ['현대차·BMW·벤츠 등 35개 차종 2만8946대 리콜',
#   '경향신문',
#   '경제>자동차 | IT_과학>인터넷_SNS | IT_과학>보안',
#   '2021/08/11',
#   '김희진 기자 hjin@kyunghyang.com'],
#  ['박용진 "4차 산업혁명 선도하는 \'바이미식스\' 대통령 되겠다"',
#   '경향신문',
#   '정치>국회_정당 | 정치>선거 | 정치>청와대',
#   '2021/08/11',
#   '탁지영 기자 g0g0@kyunghyang.com'],
#  ['이준석 \'친윤석열계\' 겨냥 "권력욕 부추기는 하이에나"..정진석 "참 딱하다"',
#   '경향신문',
#   '정치>국회_정당 | 정치>선거',
#   '2021/08/11',
#   '유정인 기자 jeongin@kyunghyang.com']]

# %%
len(texts)

# %%
wholes = soup.select('div.news-inner')

# %%
len(wholes)

# %%
whole = wholes[0]

# %%
len(contents)

# %%
len(texts)

# %%
sample = []
for t in texts:
    for content in contents:
        print(content.append(t))

# %%
df = pd.DataFrame(data=contents, columns =['title', 'press', 'category', 'date', 'name'])
df
# Out:
#                                           title press  \
# 0      [뉴스분석]이준석과 윤석열은 왜 대립할까···‘투스톤’의 이유있는 신경전  경향신문
# 1                          중국에 대립각 세우는 리투아니아…왜?  경향신문
# 2              국민의힘, 계속 옮겨붙는 갈등의 불씨...진화할 수 있을까  경향신문
# 3   [단독] 법관이 직원에게 성경 공부·의전 지시, 법원에서도 ‘직장 갑질’ 논란  경향신문
# 4          코로나 확진자수 2000명 돌파에 노심초사 여, 공세 강화하는 야  경향신문
# ..                                          ...   ...
# 95        죽파리 자작나무 숲 인근 ‘송하리 졸참나무와 당숲’ 천연기념물 된다  경향신문
# 96             섬유·제지 산업도 탄소중립 움직임···"폐자원을 에너지로"  경향신문
# 97               현대차·BMW·벤츠 등 35개 차종 2만8946대 리콜  경향신문
# 98           박용진 "4차 산업혁명 선도하는 '바이미식스' 대통령 되겠다"  경향신문
# 99  이준석 '친윤석열계' 겨냥 "권력욕 부추기는 하이에나"..정진석 "참 딱하다"  경향신문
#
#                              category        date  \
# 0                    정치>선거 | 정치>국회_정당  2021/08/11
# 1            국제>중국 | 정치>외교 | 국제>유럽_EU  2021/08/11
# 2                    정치>선거 | 정치>국회_정당  2021/08/11
# 3         국제>미국_북미 | 국제>유럽_EU | 사회>여성  2021/08/11
# 4                   정치>국회_정당 | 정치>청와대  2021/08/11
# ..                                ...         ...
# 95       문화>학술_문화재 | 문화>미술_건축 | 지역>강원  2021/08/11
# 96             경제>반도체 | 지역>강원 | 지역>충남  2021/08/11
# 97  경제>자동차 | IT_과학>인터넷_SNS | IT_과학>보안  2021/08/11
# 98          정치>국회_정당 | 정치>선거 | 정치>청와대  2021/08/11
# 99                   정치>국회_정당 | 정치>선거  2021/08/11
#
#                                  name
# 0     박순봉·유정인 기자 gabgu@kyunghyang.com
# 1      박은하 기자 eunha999@kyunghyang.com
# 2   유정인·박순봉 기자 jeongin@kyunghyang.com
# 3           이혜리 기자 lhr@kyunghyang.com
# 4         유설희 기자 sorry@kyunghyang.com
# ..                                ...
# 95         김종목 기자 jomo@kyunghyang.com
# 96         강연주 기자 play@kyunghyang.com
# 97         김희진 기자 hjin@kyunghyang.com
# 98         탁지영 기자 g0g0@kyunghyang.com
# 99      유정인 기자 jeongin@kyunghyang.com
#
# [100 rows x 5 columns]

# %%
df['text'] = texts
df
# Out:
#                                           title press  \
# 0      [뉴스분석]이준석과 윤석열은 왜 대립할까···‘투스톤’의 이유있는 신경전  경향신문
# 1                          중국에 대립각 세우는 리투아니아…왜?  경향신문
# 2              국민의힘, 계속 옮겨붙는 갈등의 불씨...진화할 수 있을까  경향신문
# 3   [단독] 법관이 직원에게 성경 공부·의전 지시, 법원에서도 ‘직장 갑질’ 논란  경향신문
# 4          코로나 확진자수 2000명 돌파에 노심초사 여, 공세 강화하는 야  경향신문
# ..                                          ...   ...
# 95        죽파리 자작나무 숲 인근 ‘송하리 졸참나무와 당숲’ 천연기념물 된다  경향신문
# 96             섬유·제지 산업도 탄소중립 움직임···"폐자원을 에너지로"  경향신문
# 97               현대차·BMW·벤츠 등 35개 차종 2만8946대 리콜  경향신문
# 98           박용진 "4차 산업혁명 선도하는 '바이미식스' 대통령 되겠다"  경향신문
# 99  이준석 '친윤석열계' 겨냥 "권력욕 부추기는 하이에나"..정진석 "참 딱하다"  경향신문
#
#                              category        date  \
# 0                    정치>선거 | 정치>국회_정당  2021/08/11
# 1            국제>중국 | 정치>외교 | 국제>유럽_EU  2021/08/11
# 2                    정치>선거 | 정치>국회_정당  2021/08/11
# 3         국제>미국_북미 | 국제>유럽_EU | 사회>여성  2021/08/11
# 4                   정치>국회_정당 | 정치>청와대  2021/08/11
# ..                                ...         ...
# 95       문화>학술_문화재 | 문화>미술_건축 | 지역>강원  2021/08/11
# 96             경제>반도체 | 지역>강원 | 지역>충남  2021/08/11
# 97  경제>자동차 | IT_과학>인터넷_SNS | IT_과학>보안  2021/08/11
# 98          정치>국회_정당 | 정치>선거 | 정치>청와대  2021/08/11
# 99                   정치>국회_정당 | 정치>선거  2021/08/11
#
#                                  name  \
# 0     박순봉·유정인 기자 gabgu@kyunghyang.com
# 1      박은하 기자 eunha999@kyunghyang.com
# 2   유정인·박순봉 기자 jeongin@kyunghyang.com
# 3           이혜리 기자 lhr@kyunghyang.com
# 4         유설희 기자 sorry@kyunghyang.com
# ..                                ...
# 95         김종목 기자 jomo@kyunghyang.com
# 96         강연주 기자 play@kyunghyang.com
# 97         김희진 기자 hjin@kyunghyang.com
# 98         탁지영 기자 g0g0@kyunghyang.com
# 99      유정인 기자 jeongin@kyunghyang.com
#
#                                                  text
# 0   이준석 국민의힘 대표와 당내 ‘1위 대선 주자’인 윤석열 전 검찰총장의 계속되는 신...
# 1   중국에서 6000km 떨어진 발트해 연안 국가 리투아니아가 ‘대만 문제’를 두고 중...
# 2   국민의힘 내홍이 깊어지고 있다. 이준석 대표와 윤석열 전 검찰총장 등 ‘투스톤(준스...
# 3   법관에게 직장 내 갑질 및 괴롭힘을 당했다며 도움을 호소하는 법원 직원의 글이 법원...
# 4   코로나19 신규 확진자가 11일 사상 처음으로 2000명을 돌파하자 여권은 ‘노심초...
# ..                                                ...
# 95  문화재청이 ‘영양 송하리 졸참나무와 당숲’을 국가지정문화재 천연기념물로 지정 예고했...
# 96  정부가 섬유·제지 산업에서 탄소배출량을 줄이는 기술 개발에 투자를 강화한다.산업통상...
# 97  국토교통부는 현대자동차와 BMW 등 35개 차종 총 2만8946대에서 제작결함이 발...
# 98  더불어민주당 대선 경선 후보인 박용진 의원은 11일 “4차 산업혁명 대통령이 되겠다...
# 99  이준석 국민의힘 대표는 11일 “우리 후보들 곁에 권력욕을 부추기는 하이에나가 아니...
#
# [100 rows x 6 columns]

# %%
df.to_excel("C:/Users/LimTH/Desktop/practice/담아돌 곳/sample/sample.xls", header=None,index=False)

# %%
# df.to_excel('C:/Users/LimTH/Desktop/practice/담아돌 곳/sample/sample.xls', header=None,index=False)

# %%
browser.find_elements_by_css_selector('div.modal-footer > button')[0].click()

# %%
texts = []
for i in range(0,11):
    time.sleep(0.5)
    browser.find_elements_by_css_selector('span.title-elipsis')[i].click()
    text = browser.find_elements_by_css_selector('div.modal-body > div > div.news-view-body')[0].text
    texts.append(text)
    time.sleep(0.5)
    browser.find_element_by_xpath("//div[@id='news-detail-modal']/div/div/button").click()

# %%
texts = []
browser.find_elements_by_css_selector('span.title-elipsis')[1].click()
text = browser.find_elements_by_css_selector('div.modal-body > div > div.news-view-body')[0].text
time.sleep(1)
texts.append(text)
browser.find_element_by_xpath("//div[@id='news-detail-modal']/div/div/button").click()
texts

# %%
texts

# %%
texts = []
for i in range(0,11):
    time.sleep(0.5)
    browser.find_elements_by_css_selector('span.title-elipsis')[i].click()
    text = browser.find_elements_by_css_selector('div.modal-body > div > div.news-view-body')[0].text
    texts.append(text)
#     browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
    time.sleep(0.5)
    browser.find_element_by_xpath("//div[@id='news-detail-modal']/div/div/button").click()
#     WebDriverWait(browser, 1)
#     WebDriverWait(browser, 3).until(EC.element_to_be_clickable((By.CSS_SELECTOR, 'div.modal-footer > button')))
#     browser.find_elements_by_css_selector('div.modal-footer > button')[0].click()
texts

# %%
texts

# %%
html = browser.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
wholes = soup.select('div.news-inner')

# %%
contents = list() # [제목, 언론사, 분류, 날짜, 기자이름, 기사내용]
for whole in wholes:
    title = whole.select('span.title-elipsis')
    press =  whole.select('div.info > div > a')
    category = whole.select('div.info > div > span.bullet-keyword')
    date_name = whole.select('div.info > p')
    contents.append([title[0].text.strip(), press[0].text.strip(), category[0].text.strip(), date_name[0].text.strip(), date_name[1].text.strip()])

# %%
contents[1]

# %%
texts = []
for i in range(0,3):
    time.sleep(0.5)
    browser.find_elements_by_css_selector('span.title-elipsis')[i].click()
    text = browser.find_elements_by_css_selector('div.news-view-body')[0].text
    texts.append(text)
    time.sleep(0.5)
    browser.find_element_by_xpath("//div[@id='news-detail-modal']/div/div/button").click()
#     browser.find_elements_by_css_selector('div.modal-footer > button')[0].click()

# %%
texts

# %%
texts = []

# %%
texts = []
for i in range(0, 11):
    browser.find_elements_by_css_selector('span.title-elipsis')[i].click()
    time.sleep(1)
    text = browser.find_elements_by_css_selector('div.news-view-body')[0].text
    texts.append(text)
    browser.find_elements_by_css_selector('div.modal-footer > button')[0].click()
texts

# %%
texts[5]

# %%
texts = []

# %%
browser.find_elements_by_css_selector('span.title-elipsis')[0].click()

# %%
text = browser.find_elements_by_css_selector('div.news-view-body')[0].text

# %%
texts.append(text)

# %%
browser.find_elements_by_css_selector('div.modal-footer > button')[0].click()

# %%
texts

# %%
browser.find_elements_by_css_selector('span.title-elipsis')[60].click()

# %%
text = browser.find_elements_by_css_selector('div.news-view-body')[0].text
texts.append(text.replace('\n', ''))

# %%
browser.find_element_by_xpath("//div[@id='news-detail-modal']/div/div/button").click()

# %%
browser.find_elements_by_css_selector('div.modal-footer > button')[0].click()

# %%
texts[2]

# %%
modal-close

# %%
div.modal-footer > button.btn

# %%
soup.select('div.news-view-body')
div.modal-footer > button.btn
